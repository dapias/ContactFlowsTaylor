# %% [markdown]
# # Nosé-Hoover harmonic oscillator. Gibbs distribution using the parameters given by Tuckerman book.

# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
include("../Nose-HooverTaylor.jl");

# %%
condinic = [0., 1.,0.,1.] #q, p, eta, p_eta;

# %%
nsteps = 20000; 
ndescarte = 100; #Descarto los primeros pasos que pueden ser inútiles para la estadística;

# %%
beta = 1.0 #beta = 1/T;

# %%
vec =NoseHooverIntegration(campoNoseHoover, nsteps, condinic, beta);

# %% [markdown]
# **vec**  es una tupla de arreglos con entradas `(tiempo,q, p , eta,p_eta)` .
# Cada elemento de la tupla es un arreglo de longitud *nsteps*, conteniendo los resultados de la integración de l campo a cada paso de tiempo.

# %%
t = vec[1][ndescarte:end]; q = vec[2][ndescarte:end]; p = vec[3][ndescarte:end]; eta= vec[4][ndescarte:end]; p_eta=vec[5][ndescarte:end];

# %% [markdown]
# ## Espacio fase

# %%
plt[:figure](1)
plt[:plot](q, p, "g.")
plt[:xlabel]("q")
plt[:ylabel]("p")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f4552d53ad0>)
# PyObject <matplotlib.text.Text object at 0x7f452f925b90>

# %% [markdown]
# ## p(t) y q(t)

# %%
plt[:figure](1)
plt[:subplot](211)
plt[:plot](t, p, "r.")
plt[:xlabel]("t")
plt[:ylabel]("p")

plt[:subplot](212)
plt[:plot](t, q, "b.")
plt[:xlabel]("t")
plt[:ylabel]("q")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f452fd766d0>)
# PyObject <matplotlib.text.Text object at 0x7f452f353710>

# %% [markdown]
# # Histogramas

# %%
nbins =50;

# %%
plt[:hist](p, nbins, normed = 1)
plt[:xlabel]("p")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f452fb7b4d0>)
# PyObject <matplotlib.text.Text object at 0x7f452f27ef10>

# %%
E = (p.^2 + q .^2)/2.;

# %%
plt[:hist](E, nbins, normed =1);
plt[:xlabel]("E");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f452f2ca690>)

# %%
k = 0.
# Out:
# 0.0

# %%
if k != 0.
    println("hkoao")
end
