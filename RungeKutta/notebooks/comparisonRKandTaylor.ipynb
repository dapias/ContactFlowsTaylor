# %% [markdown]
# # Comparing the adaptive stepsize Runge-Kutta and Taylor Series methods

# %%
using PyPlot

# %% [markdown]
# ## Time of integration

# %%
pwd()
# Out:
# "/home/diegotap/ContactTaylor/RungeKutta/notebooks"

# %%
##Use what pwd() prints

# %%
;cd /home/diegotap/ContactTaylor/RungeKutta/notebooks
# Out:
# /home/diegotap/ContactTaylor/RungeKutta/notebooks

# %%
;cd ..
# Out:
# /home/diegotap/ContactTaylor/RungeKutta

# %%
@time include("contact_rungekode45.jl")
# Out:
# Type the output filename (without a format):
# STDIN> test
# The simulation was succesfully done.
# Output in /HDF5/tes.hdf5
#  21.178559 seconds (331.24 M allocations: 7.951 GB, 2.57% gc time)

# %%
; cd ..
# Out:
# /home/diegotap/ContactTaylor

# %%
@time include("contact_taylor.jl")
# Out:
# Type the output filename (without a format):
# STDIN> test1
# The filename typed already exists in the HDF5 folder. Try another one:
# STDIN> test11
# The simulation was succesfully done.
# Output in /HDF5/test11.hdf5
# 144.183401 seconds (1.98 G allocations: 163.497 GB, 12.22% gc time)

# %% [markdown]
# ## Results of the integration

# %%
pwd()
# Out:
# "/home/diegotap/ContactTaylor"

# %%
filename = "test11.hdf5" #The file must exist in the HDF5 folder
taylorfile = h5open("./HDF5/$filename", "r")
# Out:
# HDF5 data file: ./HDF5/test11.hdf5

# %%
;cd ./RungeKutta
# Out:
# /home/diegotap/ContactTaylor/RungeKutta

# %%
filename = "test11.hdf5"
rkfile = h5open("./HDF5/$filename", "r")
# Out:
# HDF5 data file: ./HDF5/test11.hdf5

# %%
simt = read(taylorfile, "simulation-1");
tt = simt["t"]
qt = simt["q"]
pt = simt["p"]
St = simt["S"];

# %%
simr = read(rkfile, "simulation-1");
tr = simr["t"]
qr = simr["q"]
pr = simr["p"]
Sr = simr["S"];

# %%
plot(tt - tr)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f84f31ecc50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f84f2749390>

# %%
plot(pt[1:1000] - pr[1:1000])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f84f2749e10>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f84f252f150>

# %%
plot(qt[1:1000] - qr[1:1000])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f84f256f150>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f84f245b390>

# %%
plot(St[1:1000] - Sr[1:1000])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f84f23fb3d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f84f238d510>
