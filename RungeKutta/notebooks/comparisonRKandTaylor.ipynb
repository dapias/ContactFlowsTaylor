# %% [markdown]
# # Comparing the adaptive stepsize Runge-Kutta and Taylor Series methods

# %%
using PyPlot

# %% [markdown]
# ## Time of integration

# %%
pwd()
# Out:
# "/home/diegotap/ContactTaylor/RungeKutta/notebooks"

# %%
#Use what pwd() prints

# %%
;cd /home/diegotap/ContactTaylor/RungeKutta/notebooks
# Out:
# /home/diegotap/ContactTaylor/RungeKutta/notebooks

# %%
;cd ..
# Out:
# /home/diegotap/ContactTaylor/RungeKutta

# %%
@time include("contact_rungekode45.jl")
# Out:
# Type the output filename (without a format):
# STDIN> fooo
# The simulation was succesfully done.
# Output in /HDF5/foo.hdf5
#  43.671110 seconds (636.46 M allocations: 14.575 GB, 2.45% gc time)

# %%
; cd ..
# Out:
# /home/diegotap/ContactTaylor

# %%
@time include("contact_taylor.jl")
# Out:
# Type the output filename (without a format):
# STDIN> barr
# The simulation was succesfully done.
# Output in /HDF5/bar.hdf5
#  25.312498 seconds (259.00 M allocations: 21.520 GB, 9.18% gc time)

# %% [markdown]
# ## Results of the integration

# %%
pwd()
# Out:
# "/home/diegotap/ContactTaylor"

# %%
filename = "bar.hdf5" #The file must exist in the HDF5 folder
taylorfile = h5open("./HDF5/$filename", "r")
# Out:
# HDF5 data file: ./HDF5/bar.hdf5

# %%
;cd ./RungeKutta
# Out:
# /home/diegotap/ContactTaylor/RungeKutta

# %%
filename = "foo.hdf5"
rkfile = h5open("./HDF5/$filename", "r")
# Out:
# HDF5 data file: ./HDF5/foo.hdf5

# %%
simt = read(taylorfile, "simulation-1");
tt = simt["t"]
qt = simt["q"]
pt = simt["p"]
St = simt["S"];

# %%
simr = read(rkfile, "simulation-1");
tr = simr["t"]
qr = simr["q"]
pr = simr["p"]
Sr = simr["S"];

# %%
plot(pt-pr)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4237119110>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f4236ff6c90>

# %%
plot(qt-qr)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4237037890>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f4236f38250>

# %%
plot(St-Sr)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f42372d2450>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f4236e7e650>
