# %% [markdown]
# # Comparing the adaptive stepsize Runge-Kutta and Taylor Series methods

# %%
using PyPlot

# %% [markdown]
# ## Time of integration

# %%
pwd()
# Out:
# "/home/diegotap/ContactTaylor/RungeKutta/notebooks"

# %%
;cd /home/diegotap/ContactTaylor/RungeKutta/notebooks
# Out:
# /home/diegotap/ContactTaylor/RungeKutta/notebooks

# %%
;cd ..
# Out:
# /home/diegotap/ContactTaylor/RungeKutta

# %%
@time include("rungekode45.jl")
# Out:
# Type the output filename (without a format):
# STDIN> testt
# The filename typed already exists in the HDF5 folder. Try another one:
# STDIN> testt
# The simulation was succesfully done.
# Output in /HDF5/testt.hdf5
#  32.949598 seconds (56.58 M allocations: 1.470 GB, 0.51% gc time)

# %%
; cd ..
# Out:
# /home/diegotap/ContactTaylor

# %%
@time include("script.jl")
# Out:
# Type the output filename (without a format):
# STDIN> testt
# The simulation was succesfully done.
# Output in /HDF5/test.hdf5
# 151.454107 seconds (1.98 G allocations: 163.541 GB, 11.25% gc time)

# %% [markdown]
# ## Results of the integration

# %%
pwd()
# Out:
# "/home/diegotap/ContactTaylor/RungeKutta"

# %%
filename = "test.hdf5" #The file must exist in the HDF5 folder
taylorfile = h5open("./HDF5/$filename", "r")
# Out:
# HDF5 data file: ./HDF5/test.hdf5

# %%
;cd ./RungeKutta
# Out:
# LoadError: chdir ./RungeKutta: no such file or directory (ENOENT)
# while loading In[13], in expression starting on line 1
#
#  in cd at ./file.jl:13
#  in repl_cmd at client.jl:66
#  in repl_cmd at /home/diegotap/.julia/v0.4/IJulia/src/execute_request.jl:125

# %%
filename = "testt.hdf5"
rkfile = h5open("./HDF5/$filename", "r")
# Out:
# HDF5 data file: ./HDF5/testt.hdf5

# %%
simt = read(taylorfile, "simulation-1");
tt = simt["t"]
qt = simt["q"]
pt = simt["p"]
St = simt["S"];

# %%
simr = read(rkfile, "simulation-1");
tr = simr["t"]
qr = simr["q"]
pr = simr["p"]
Sr = simr["S"];

# %%
plot(tt - tr)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa99726cc50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fa994d67390>

# %%
plot(pt[1:1000] - pr[1:1000])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa994b3aed0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fa994acb510>

# %%
plot(qt[1:1000] - qr[1:1000])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa994ba7d10>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fa9949f3ed0>

# %%
plot(St[1:1000] - Sr[1:1000])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa9949aaf50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fa994932090>
